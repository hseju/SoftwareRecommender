# %% [markdown]
# ## Software Recommender System

# %%
# %%capture
# %pip install pandas
# %pip install numpy
# %pip install openpyxl
# %pip install inquirer
# %pip install flask
# %pip install SQLAlchemy
# %pip install flask_sqlalchemy

# %%
import pandas as pd
import numpy as np
import os

# %%
cwd = os.getcwd()

df = pd.read_excel(cwd+"/B2B Data Provider-sample1.xlsx")

# %% [markdown]
# ## Preprocessing Data

# %%
#printing columns
print(df.columns)
# Out:
# Index(['Company', 'Starting Price - Monthly', 'Starting Price - Annually',
#        'Pricing Range', 'Pricing comments', 'Additional Pricing Info',
#        'Website', 'Contract', 'Solutions', 'Unlimited Data Plan',
#        'CRM Integrations', 'SEPI', 'SalesTeamType', 'Free Trial',
#        'ContactEnrichment', 'IntentData', 'Other', 'location'],
#       dtype='object')

# %%
#removing unnecessary columns
df_pro = df.drop(['Additional Pricing Info','Website','Unlimited Data Plan'], axis=1) 
df_pro.head()
# Out:
#     Company  Starting Price - Monthly  Starting Price - Annually  \
# 0  ZoomInfo                         0                      11995
# 1   Cognism                         0                      16500
# 2    Uplead                        99                        888
# 3   Lead411                        99                        900
# 4    Apollo                        49                          0
#
#                                        Pricing Range  \
# 0  Single user Pro Lite: $11,995 – 5,000 credits ...
# 1                                     16,500-27,500+
# 2  $888 annual, $99 per month, month to month -  ...
# 3  $99 per month, month to month-$1800+ per year ...
# 4    $49 per month, month to month - $6000 per year+
#
#                   Pricing comments           Contract  \
# 0       based on users and credits             Annual
# 1  based on platform fee and users             Annual
# 2                 based on credits  Annual or Monthly
# 3        based on credits/contacts  Annual or Monthly
# 4           based on credits/users  Annual or Monthly
#
#                   Solutions  \
# 0  email, workphone, mobile
# 1  email, workphone, mobile
# 2  email, workphone, mobile
# 3  email, workphone, mobile
# 4  email, workphone, mobile
#
#                                     CRM Integrations  \
# 0  Microsoft Dynamics, HubSpot, Salesforce, Piped...
# 1      Salesforce, HubSpot, Pipedrive, and Dynamics.
# 2  Salesforce, HubSpot, Insightly, Pipedrive, Zoh...
# 3  Salesforce, HubSpot, Pipedrive, and Microsoft ...
# 4                                Salesforce, HubSpot
#
#                                                 SEPI  \
# 0                                Outreach, Salesloft
# 1                                          Salesloft
# 2  Outreach, Salesloft, Reply, Woodpecker, Lemlis...
# 3                                                NaN
# 4                                Salesloft, Outreach
#
#                   SalesTeamType Free Trial ContactEnrichment IntentData  \
# 0  SMB, Mid-Market, Enterprise         yes               Yes        Yes
# 1  SMB, Mid-Market, Enterprise         yes               Yes        Yes
# 2  SMB, Mid-Market, Enterprise         yes               Yes        Yes
# 3  SMB, Mid-Market, Enterprise         yes               Yes        Yes
# 4  SMB, Mid-Market, Enterprise         yes               Yes         No
#
#                                                Other       location
# 0  many other add ons, like Chorus.ai, focused on...            NaN
# 1                       International data is strong  International
# 2                                                NaN            NaN
# 3                                                NaN            NaN
# 4  Best overall value, includes a sales engagemen...            NaN

# %%
#replace all Nan values with -

df_pro = df_pro.replace(np.nan, "-")

# %% [markdown]
# ## READ the User data

# %%
df_user = pd.read_csv("user_data.csv", index_col=0)

# %%
df_user
# Out:
#                                 data               contract     duration  \
# 0  ['Email', 'Work Phone', 'Mobile']  ['Monthly', 'Annual']  ['Monthly']
#
#    price location  user    tools                              features  \
# 0    800  ['All']     2  ['All']  ['ContractEnrichment', 'IntentData']
#
#        crm
# 0  ['All']

# %%
#data and contract done
data = df_user['data'].item().replace("'", "").strip("[]").replace(" ","").lower().split(",")
contract = df_user['contract'].item().replace("'", "").strip("[]").replace(" ","").split(",")
data, contract
# Out:
# (['email', 'workphone', 'mobile'], ['Monthly', 'Annual'])

# %%
#duration and price
duration = df_user['duration'].item().replace("'", "").strip("[]")
price = df_user['price'].item()
duration, price
# Out:
# ('Monthly', 800)

# %%
#tools and features
tools = df_user['tools'].item().replace("'", "").strip("[]").replace(" ","").split(",")
features = df_user['features'].item().replace("'", "").strip("[]").replace(" ","").split(",")

# %%
#crm
crm = df_user['crm'].item().replace("'", "").strip("[]").replace(" ","").split(",")

# %%
result = df_pro[df_pro['Contract'].str.contains(r'\b(?:{})\b'.format('|'.join(contract)))].reset_index(drop=True)

if len(result) >3 and (len(result)-1!=1):
    result = result[result['Solutions'].str.contains(r'\b(?:{})\b'.format('|'.join(data)))].reset_index(drop=True)
else:
    result = result.copy()

if len(result) >3 and (len(result)-1!=1):
    if duration in df_pro.columns[1]:
        result = result[result['Starting Price - Monthly'] <= price].reset_index(drop=True)
    elif duration in df_pro.columns[2]:
        result = result[result['Starting Price - Annually'] <= price].reset_index(drop=True)
    else: 
        pass
else:
    result = result.copy()



if len(result) >3 and (len(result)-1!=1):
    #location
    try:
        if df_user['location'].str == "International":
            result = result[result['location']=="International"]
        elif df_user['location'].str == "Domestic":
            result = result[result['location']=="Domestic"]
        else:
            result = result.copy()
    except ValueError:
        print(f"No {df_user['location'].str} not found.")
        
else:
    result = result.copy()


if len(result) >3 and (len(result)-1!=1): 
    if not "All" in tools:
        result = result[result['SEPI'].str.contains(r'\b(?:{})\b'.format('|'.join(tools)))].reset_index(drop=True)
    else:
        pass
else:
    result = result.copy()
    
    
     
if len(result) >3 and (len(result)-1!=1):
    try:
        result= result[result['features']==features[0]]
    except:
        pass
else:
    result = result.copy()
    
    
if len(result)> 3 and (len(result)-1!=1):
    try:
        result= result[result['features']==features[1]]
    except:
        pass
else:
    result = result.copy()

if len(result)>3 and (len(result)-1!=1):  
    if not "All" in crm:
        result = result[result['CRM Integrations'].str.contains(r'\b(?:{})\b'.format('|'.join(crm)))].reset_index(drop=True)
    else:
        pass
    
else:
    result = result.copy()

# %%
result
# Out:
#        Company  Starting Price - Monthly  Starting Price - Annually  \
# 0     ZoomInfo                         0                      11995
# 1      Cognism                         0                      16500
# 2       Uplead                        99                        888
# 3      Lead411                        99                        900
# 4       Apollo                        49                          0
# 5     Seamless                         0                       1764
# 6  RocketReach                        80                        468
# 7        Lusha                        39                        348
# 8   Crunchbase                         0                        348
# 9      Snov.io                        39                        396
#
#                                        Pricing Range  \
# 0  Single user Pro Lite: $11,995 – 5,000 credits ...
# 1                                     16,500-27,500+
# 2  $888 annual, $99 per month, month to month -  ...
# 3  $99 per month, month to month-$1800+ per year ...
# 4    $49 per month, month to month - $6000 per year+
# 5                  $1764 per year to $9528 per year+
# 6                   $80 per month to $6000 per year+
# 7                 $39 per monmth to $1,140 per year+
# 8                                                348
# 9                           $39 per month to & 7,380
#
#                   Pricing comments           Contract  \
# 0       based on users and credits             Annual
# 1  based on platform fee and users             Annual
# 2                 based on credits  Annual or Monthly
# 3        based on credits/contacts  Annual or Monthly
# 4           based on credits/users  Annual or Monthly
# 5           based on credits/users             Annual
# 6           based on credits/users  Annual or Monthly
# 7           based on credits/users  Annual or Monthly
# 8           based on credits/users  Annual or Monthly
# 9           based on credits/users             Annual
#
#                   Solutions  \
# 0  email, workphone, mobile
# 1  email, workphone, mobile
# 2  email, workphone, mobile
# 3  email, workphone, mobile
# 4  email, workphone, mobile
# 5  email, workphone, mobile
# 6  email, workphone, mobile
# 7         email, workphone,
# 8                     email
# 9                     email
#
#                                     CRM Integrations  \
# 0  Microsoft Dynamics, HubSpot, Salesforce, Piped...
# 1      Salesforce, HubSpot, Pipedrive, and Dynamics.
# 2  Salesforce, HubSpot, Insightly, Pipedrive, Zoh...
# 3  Salesforce, HubSpot, Pipedrive, and Microsoft ...
# 4                                Salesforce, HubSpot
# 5  Salesforce, HubSpot, Microsoft Dynamics, Keap,...
# 6                                Salesforce, HubSpot
# 7                                Salesforce, HubSpot
# 8                                         Salesforce
# 9                                                  -
#
#                                                 SEPI  \
# 0                                Outreach, Salesloft
# 1                                          Salesloft
# 2  Outreach, Salesloft, Reply, Woodpecker, Lemlis...
# 3                                                  -
# 4                                Salesloft, Outreach
# 5                                Salesloft, Outreach
# 6                                Salesloft, Outreach
# 7                                Salesloft, Outreach
# 8                                                  -
# 9  HubSpot, Salesforce, Pipedrive, Nutshell, Zoho...
#
#                   SalesTeamType Free Trial ContactEnrichment IntentData  \
# 0  SMB, Mid-Market, Enterprise         yes               Yes        Yes
# 1  SMB, Mid-Market, Enterprise         yes               Yes        Yes
# 2  SMB, Mid-Market, Enterprise         yes               Yes        Yes
# 3  SMB, Mid-Market, Enterprise         yes               Yes        Yes
# 4  SMB, Mid-Market, Enterprise         yes               Yes         No
# 5               SMB, Mid-Market        yes               Yes         No
# 6               SMB, Mid-Market        yes                No         No
# 7                           SMB        yes               Yes         No
# 8  SMB, Mid-Market, Enterprise         yes                No         No
# 9               SMB, Mid-Market        yes                No         No
#
#                                                Other       location
# 0  many other add ons, like Chorus.ai, focused on...              -
# 1                       International data is strong  International
# 2                                                  -              -
# 3                                                  -              -
# 4  Best overall value, includes a sales engagemen...              -
# 5                                                  -              -
# 6                                                  -              -
# 7                           for SMBs, GDPR compliant              -
# 8                        best for targeting startups              -
# 9                         great value for email only              -

# %%
list_of_companies = result['Company']

# %%
list_of_companies[0]
# Out:
# 'Uplead'

# %%
print(f"The top three recommendations are: \n{list_of_companies[0]} \n{list_of_companies[1]} \n{list_of_companies[2]}")
# Out:
# The top three recommendations are:
# Uplead
# Apollo
# Seamless

# %%
result = df_pro[df_pro['Contract'].str.contains(r'\b(?:{})\b'.format('|'.join(contract)))].reset_index(drop=True)

result = result[result['Solutions'].str.contains(r'\b(?:{})\b'.format('|'.join(data)))].reset_index(drop=True)
if len(result) >3:
    if duration in df_pro.columns[1]:
        result = result[result['Starting Price - Monthly'] <= price].reset_index(drop=True)
    elif duration in df_pro.columns[2]:
        result = result[result['Starting Price - Annually'] <= price].reset_index(drop=True)
    else: 
        pass
    

if len(result) >3:
    #location
    try:
        if df_user['location'].str == "International":
            result = result[result['location']=="International"]
        elif df_user['location'].str == "Domestic":
            result = result[result['location']=="Domestic"]
        else:
            pass
    except ValueError:
        print(f"No {df_user['location'].str} not found.")
        
if len(result) >3:
    result = result[result['SEPI'].str.contains(r'\b(?:{})\b'.format('|'.join(tools)))].reset_index(drop=True)
    
if len(result) >3:
    try:
        result= result[result['ContactEnrichment']==features[0]]
    except:
        pass
    
    
if len(result)>3:
    try:
        result= result[result['IntentData']==features[1]]
    except:
        pass

    
result
# Out:
#   Company  Starting Price - Monthly  Starting Price - Annually  \
# 0  Uplead                        99                        888
#
#                                        Pricing Range  Pricing comments  \
# 0  $888 annual, $99 per month, month to month -  ...  based on credits
#
#             Contract                 Solutions  \
# 0  Annual or Monthly  email, workphone, mobile
#
#                                     CRM Integrations  \
# 0  Salesforce, HubSpot, Insightly, Pipedrive, Zoh...
#
#                                                 SEPI  \
# 0  Outreach, Salesloft, Reply, Woodpecker, Lemlis...
#
#                   SalesTeamType Free Trial ContactEnrichment IntentData Other  \
# 0  SMB, Mid-Market, Enterprise         yes               Yes        Yes     -
#
#   location
# 0        -

# %%
price = ''

# %%
price
# Out:
# ''

# %%
if price != '':
    print("not empty")
else:
    print("price empty")
# Out:
# price empty
